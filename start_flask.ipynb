# %% [markdown]
# ## Run Flask
# Run your flask app (`wsgi.py`) from here and test it from a separate notebook.

# %%
import sys
# !{sys.executable} -m pip install -r requirements.txt

#!FLASK_ENV=development FLASK_APP=wsgi.py flask run 
# !FLASK_ENV=development 
# !FLASK_APP=wsgi.py 
# !flask run --host=0.0.0.0

app = Flask(__name__)
if __name__ == '__main__':
    app.run(debug=True, port=5000)
# Out:
# Requirement already satisfied: requests in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (2.31.0)
# Requirement already satisfied: Flask in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: pandas in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (1.5.3)
# Requirement already satisfied: gunicorn in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (21.2.0)
# Requirement already satisfied: openpyxl in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (3.1.2)
# Requirement already satisfied: tqdm in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (4.66.1)
# Requirement already satisfied: datetime in /opt/app-root/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (5.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/app-root/lib/python3.9/site-packages (from requests->-r requirements.txt (line 1)) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/app-root/lib/python3.9/site-packages (from requests->-r requirements.txt (line 1)) (3.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/app-root/lib/python3.9/site-packages (from requests->-r requirements.txt (line 1)) (2023.7.22)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/app-root/lib/python3.9/site-packages (from requests->-r requirements.txt (line 1)) (1.26.16)
# Requirement already satisfied: itsdangerous>=2.1.2 in /opt/app-root/lib/python3.9/site-packages (from Flask->-r requirements.txt (line 2)) (2.1.2)
# Requirement already satisfied: click>=8.1.3 in /opt/app-root/lib/python3.9/site-packages (from Flask->-r requirements.txt (line 2)) (8.1.7)
# Requirement already satisfied: Werkzeug>=3.0.0 in /opt/app-root/lib/python3.9/site-packages (from Flask->-r requirements.txt (line 2)) (3.0.1)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /opt/app-root/lib/python3.9/site-packages (from Flask->-r requirements.txt (line 2)) (6.8.0)
# Requirement already satisfied: blinker>=1.6.2 in /opt/app-root/lib/python3.9/site-packages (from Flask->-r requirements.txt (line 2)) (1.7.0)
# Requirement already satisfied: Jinja2>=3.1.2 in /opt/app-root/lib/python3.9/site-packages (from Flask->-r requirements.txt (line 2)) (3.1.2)
# Requirement already satisfied: numpy>=1.20.3 in /opt/app-root/lib/python3.9/site-packages (from pandas->-r requirements.txt (line 3)) (1.24.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/app-root/lib/python3.9/site-packages (from pandas->-r requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/app-root/lib/python3.9/site-packages (from pandas->-r requirements.txt (line 3)) (2023.3.post1)
# Requirement already satisfied: packaging in /opt/app-root/lib/python3.9/site-packages (from gunicorn->-r requirements.txt (line 4)) (23.1)
# Requirement already satisfied: et-xmlfile in /opt/app-root/lib/python3.9/site-packages (from openpyxl->-r requirements.txt (line 5)) (1.1.0)
# Requirement already satisfied: zope.interface in /opt/app-root/lib/python3.9/site-packages (from datetime->-r requirements.txt (line 7)) (6.1)
# Requirement already satisfied: zipp>=0.5 in /opt/app-root/lib/python3.9/site-packages (from importlib-metadata>=3.6.0->Flask->-r requirements.txt (line 2)) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/app-root/lib/python3.9/site-packages (from Jinja2>=3.1.2->Flask->-r requirements.txt (line 2)) (2.1.3)
# Requirement already satisfied: six>=1.5 in /opt/app-root/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->-r requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: setuptools in /opt/app-root/lib/python3.9/site-packages (from zope.interface->datetime->-r requirements.txt (line 7)) (68.2.2)
#
# [notice] A new release of pip available: 22.2.2 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# Map([<Rule '/static/<filename>' (GET, HEAD, OPTIONS) -> static>,
#  <Rule '/' (GET, HEAD, OPTIONS) -> home>,
#  <Rule '/getdata/' (GET, HEAD, OPTIONS, POST) -> getdata>,
#  <Rule '/download_excel/<excel_filename>' (GET, HEAD, OPTIONS) -> download_excel>])
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://10.129.5.101:5000
# Press CTRL+C to quit
# 10.131.0.2 - - [19/Dec/2023 13:51:10] "GET /getdata/ HTTP/1.1" 200 -
# 10.131.0.2 - - [19/Dec/2023 13:51:10] "GET /static/styles.css HTTP/1.1" 304 -
# 64d0a6b1bc1ebf709906f83e|d42d1c96dfa81b89df3f4790bc3a7105
#  2023-10-01
#  2023-12-19
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  4.97it/s]
# Interupted calls: 0
#
# station_data_month [['2023-11-15 23:00:00' '2023-12-15 23:00:00']
#  [36.6 14.0]
#  [1700089200 1702681200]]
# period_exists_list [[1696118400 1698748143 1701377886]
#  [False True True]]
# 100%|█████████████████████████████████████████████| 4/4 [00:03<00:00,  1.33it/s]
# Interupted calls: 1
#
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  2.09it/s]
# Interupted calls: 0
#
# station_data_month [['2023-11-15 23:00:00' '2023-12-15 23:00:00']
#  [49.0 33.6]
#  [1700089200 1702681200]]
# period_exists_list [[1696118400 1698748143 1701377886]
#  [False True True]]
# 100%|█████████████████████████████████████████████| 4/4 [00:03<00:00,  1.29it/s]
# Interupted calls: 1
#
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  4.19it/s]
# Interupted calls: 0
#
# station_data_month [['2023-11-15 23:00:00' '2023-12-15 23:00:00']
#  [39.1 38.4]
#  [1700089200 1702681200]]
# period_exists_list [[1696118400 1698748143 1701377886]
#  [False True True]]
# 100%|█████████████████████████████████████████████| 4/4 [00:02<00:00,  1.46it/s]
# Interupted calls: 1
#
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  4.74it/s]
# Interupted calls: 0
#
# station_data_month [['2023-11-15 23:00:00' '2023-12-15 23:00:00']
#  [26.5 19.7]
#  [1700089200 1702681200]]
# period_exists_list [[1696118400 1698748143 1701377886]
#  [False True True]]
# 100%|█████████████████████████████████████████████| 4/4 [00:03<00:00,  1.29it/s]
# Interupted calls: 1
#
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  4.81it/s]
# Interupted calls: 0
#
# station_data_month [['2023-11-15 23:00:00' '2023-12-15 23:00:00']
#  [3.2 4.2]
#  [1700089200 1702681200]]
# period_exists_list [[1696118400 1698748143 1701377886]
#  [False True True]]
# 100%|█████████████████████████████████████████████| 4/4 [00:03<00:00,  1.30it/s]
# Interupted calls: 1
#
# 100%|████████████████████████████████████| 7584/7584 [00:00<00:00, 23122.15it/s]
# 100%|████████████████████████████████████| 2768/2768 [00:00<00:00, 67228.55it/s]
# 2768it [00:00, 42603.33it/s]
#
# Regnvärden kring (57.704944, 11.974411), 2023-10-01 - 2023-12-19, upplösning 30 min, 5 stationer
# Regnvärden kring (57.704944, 11.974411), 2023-10-01 - 2023-12-19, upplösning 30 min, 5 stationer
# 10.130.2.2 - - [19/Dec/2023 13:53:06] "POST /getdata/ HTTP/1.1" 302 -
# Downloading file Regnvärden kring (57.704944, 11.974411), 2023-10-01 - 2023-12-19, upplösning 30 min, 5 stationer.xlsx
# 10.130.2.2 - - [19/Dec/2023 13:53:06] "GET /download_excel/Regnvärden%20kring%20(57.704944,%2011.974411),%202023-10-01%20-%202023-12-19,%20upplösning%2030%20min,%205%20stationer.xlsx HTTP/1.1" 200 -
